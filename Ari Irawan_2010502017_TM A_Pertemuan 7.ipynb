# %%
qW = 800 
h = 10
x = 3.5
deltaT = qW/h
Tf = (deltaT)+30
v = 2.043*10**-5
k = 0.0295
Beta = 2.92*(10**-3)
Pr = 0.7
Gr = ((9.8)*Beta*qW*(x**4))/(k*(v**2))
#print(Gr)
NilaiHx = ((k/x))*(0.17)*((Gr*Pr)**0.25)
deltaT_2 = qW/NilaiHx
Tf_2 = 30+(deltaT_2/2)

#Properti udara pada suhu 104,5 0C
v_2 = 2.354*(10**-5)
k_2 = 0.0320
Beta_2 = 2.65*(10**-3)
Pr_2 = 0.695
Gr_2 = ((9.8)*Beta_2*qW*(x**4))/(k_2*(v_2**2))
NilaiHx_2 = ((k_2/x))*(0.17)*((Gr_2*Pr_2)**0.25)
deltaT_3 = qW/NilaiHx_2
Tw = deltaT_3+30
print("Suatu pancaran panas menerpa suatu permukaan logam vertikal berukuran tinggi 3,5 m dan lebarnya 2 m. logam tersebut diinsulasi dibagian belakangnya dan dicat hitam sehingga semua radiasi yang menerpa hanya hilang melalui konveksi ke lingkungan bersuhu 30 0C. Berapakah suhu rata-rata dari pelat tersebut?• Penyelesaian: peramasalahan ini diasumsikan hanya merupakan pelat yang mendapatkan fluks panas. Perkiraan nilai koefisien perpindahan panas sekitar 10 W/m2, perkiraan beda temperature antara dinding dengan lingkungan")
print(f"Suhu dinding rata-rata = {round(Tw,0)}C ")
# Out:
# Suatu pancaran panas menerpa suatu permukaan logam vertikal berukuran tinggi 3,5 m dan lebarnya 2 m. logam tersebut diinsulasi dibagian belakangnya dan dicat hitam sehingga semua radiasi yang menerpa hanya hilang melalui konveksi ke lingkungan bersuhu 30 0C. Berapakah suhu rata-rata dari pelat tersebut?• Penyelesaian: peramasalahan ini diasumsikan hanya merupakan pelat yang mendapatkan fluks panas. Perkiraan nilai koefisien perpindahan panas sekitar 10 W/m2, perkiraan beda temperature antara dinding dengan lingkungan
# Suhu dinding rata-rata = 185.0C
